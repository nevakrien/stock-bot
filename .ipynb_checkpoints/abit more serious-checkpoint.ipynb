# %%
import yahoo_fin as yf
from yahoo_fin.stock_info import get_data
import time
import datetime
import pandas as pd
from yahoo_fin import stock_info as si

import tensorflow as tf 
import numpy as np
from tensorflow.keras import layers
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # getting the right tickers
#
# some of this is shamelessly copying this:
# https://levelup.gitconnected.com/how-to-get-all-stock-symbols-a73925c16a1b
#
# things we did to clean data:
#
# 1. we removed the tickers with $.
#
#
# 2. we added exception handeling that tries similer strings to the input. (note that this is not implemented on the set itself but when fetching, leading to multiple requsts and potentialy to errors)
#
#
# 3. we have painstakingly went ahead and manualy found all exceptions and removed them if no reformating was possible.

# %%
df1 = pd.DataFrame( si.tickers_sp500() )
df2 = pd.DataFrame( si.tickers_nasdaq() )
df3 = pd.DataFrame( si.tickers_dow() )
df4 = pd.DataFrame( si.tickers_other() )

sym1 = set( symbol for symbol in df1[0].values.tolist() )
sym2 = set( symbol for symbol in df2[0].values.tolist() )
sym3 = set( symbol for symbol in df3[0].values.tolist() )
sym4 = set( symbol for symbol in df4[0].values.tolist() )

symbols = set.union( sym1, sym2, sym3, sym4 )
del(sym1, sym2, sym3, sym4,df1, df2, df3, df4)

symbols
# Out:
# {'',
#  'EL',
#  'ALLE',
#  'MXF',
#  'REMX',
#  'MLN',
#  'PIE',
#  'PINE',
#  'SONX',
#  'AMRN',
#  'SLYV',
#  'VHAQ',
#  'BSJN',
#  'LBAI',
#  'MIMO.W',
#  'STE',
#  'ONB',
#  'DNUT',
#  'ICLK',
#  'NGC',
#  'CWEB',
#  'SAI',
#  'BJDX',
#  'NSC',
#  'MINV',
#  'CZNC',
#  'MTMT',
#  'FSBC',
#  'EZA',
#  'LEGR',
#  'NMRK',
#  'NECB',
#  'SBET',
#  'ZIG',
#  'FLRT',
#  'YCS',
#  'FSMB',
#  'CFG$D',
#  'PID',
#  'RIGZ',
#  'ERO',
#  'SSU.W',
#  'CBD',
#  'GRMN',
#  'IQSU',
#  'EPP',
#  'HYGW',
#  'SBBA',
#  'IP',
#  'VIVE',
#  'SPYG',
#  'SAL',
#  'BFI',
#  'ZHDG',
#  'FOXWW',
#  'FEMA',
#  'POET',
#  'IVR',
#  'IAE',
#  'PSTL',
#  'USI',
#  'IFRA',
#  'EDUT',
#  'FRWAU',
#  'HPKEW',
#  'ALVOW',
#  'AXTI',
#  'DFS',
#  'FLFR',
#  'GEF',
#  'GLRY',
#  'MFIN',
#  'SBUX',
#  'JRO',
#  'MDWD',
#  'HNNA',
#  'MNTS',
#  'PWUPW',
#  'WRAC.U',
#  'GBR',
#  'NFNT',
#  'SPE',
#  'AEL$B',
#  'WCN',
#  'NCMI',
#  'GSLC',
#  'API',
#  'HCKT',
#  'KREF',
#  'CFFI',
#  'VIOO',
#  'CLVR',
#  'FFWM',
#  'SMFL',
#  'PDN',
#  'JOFFW',
#  'EDNC',
#  'BIGZ',
#  'MAPS',
#  'VUZI',
#  'SPXT',
#  'IVCAU',
#  'SINT',
#  'LOCL',
#  'VISL',
#  'AFTR.U',
#  'AQB',
#  'QLTA',
#  'GTX',
#  'HIL',
#  'CENX',
#  'MFGP',
#  'TSLL',
#  'BGR',
#  'GXTG',
#  'MSGR',
#  'SMIG',
#  'DBEM',
#  'IVRA',
#  'AAPB',
#  'VXX',
#  'TTAC',
#  'DHI',
#  'RMGC',
#  'HBNC',
#  'SQLLW',
#  'IGA',
#  'OLED',
#  'SLN',
#  'GTXAP',
#  'CLSE',
#  'TLH',
#  'SIO',
#  'HYZD',
#  'IQI',
#  'SCRM',
#  'LWLG',
#  'HNST',
#  'KRTX',
#  'KZIA',
#  'TBCP',
#  'CSX',
#  'GIB',
#  'CPAAW',
#  'NNVC',
#  'EW',
#  'ITW',
#  'UBND',
#  'AXH.W',
#  'VOD',
#  'LAC',
#  'EDTXU',
#  'TXRH',
#  'TCFC',
#  'USCTU',
#  'HCIC',
#  'SNRHW',
#  'CCRN',
#  'FSS',
#  'NSSC',
#  'SCAQU',
#  'PWV',
#  'FLYA',
#  'ALTUW',
#  'AAM$A',
#  'GATX',
#  'EVEX.W',
#  'BHLB',
#  'CLDT',
#  'PAFOU',
#  'VLY',
#  'WBIY',
#  'CNO',
#  'SNV$E',
#  'NVR',
#  'MMX',
#  'PCSA',
#  'TILE',
#  'WFC$Y',
#  'XTLB',
#  'APTV',
#  'MEXX',
#  'BRG$C',
#  'XDNA',
#  'LCF',
#  'GLYC',
#  'DWMF',
#  'SPKB',
#  'ASO',
#  'OI',
#  'SMWB',
#  'SANG',
#  'PSCJ',
#  'PNFP',
#  'IXN',
#  'SRC$A',
#  'AXGN',
#  'VPN',
#  'FSRX',
#  'MHH',
#  'HDSN',
#  'FCCO',
#  'MTBC',
#  'HAS',
#  'ELV',
#  'IMCG',
#  'PGRWW',
#  'DRH$A',
#  'RS',
#  'TCPC',
#  'EKAR',
#  'CIM$C',
#  'GTHX',
#  'WSFS',
#  'PANL',
#  'TSM',
#  'PJUL',
#  'GNMA',
#  'RKT',
#  'AVHI',
#  'DECAU',
#  'LMAOW',
#  'GEEX',
#  'TELA',
#  'HTD',
#  'AEAEU',
#  'CMRE$E',
#  'FEXDW',
#  'CEA',
#  'SMMT',
#  'BNIXR',
#  'LEXI',
#  'CIRC',
#  'BYM',
#  'GASS',
#  'FWP',
#  'SIXS',
#  'DM',
#  'IMH',
#  'GWII',
#  'HONE',
#  'HMPT',
#  'ROCAU',
#  'SPY',
#  'FFHG',
#  'REV',
#  'CLFD',
#  'QPX',
#  'GCP',
#  'CLDL',
#  'STRY.W',
#  'CASI',
#  'STRT',
#  'PBFX',
#  'BYNO',
#  'BYOB',
#  'RJA',
#  'CII',
#  'IRRX.W',
#  'SWSSU',
#  'PHYS',
#  'LYT',
#  'LFG',
#  'CTAQW',
#  'SABS',
#  'LLL',
#  'CACI',
#  'NSTG',
#  'AHT$D',
#  'MXCT',
#  'MDLZ',
#  'LYLT',
#  'PSCX',
#  'KMI',
#  'RSX',
#  'GWRE',
#  'FVIV',
#  'BSFC',
#  'SSYS',
#  'AMTX',
#  'GGMCU',
#  'ZAZZT',
#  'IVCA',
#  'ACP',
#  'SCOR',
#  'MEAR',
#  'BAC$O',
#  'BHSEW',
#  'MS$F',
#  'DNAB',
#  'AMLP',
#  'SRVR',
#  'VFQY',
#  'EWO',
#  'KCAC.W',
#  'SHAP.U',
#  'AVAH',
#  'SLNH',
#  'IGI',
#  'FENG',
#  'KNGS',
#  'AXLA',
#  'SKYT',
#  'BSMR',
#  'RENEW',
#  'EPRE',
#  'KHYB',
#  'PCG$H',
#  'USAI',
#  'JZRO',
#  'SCUA.U',
#  'PEP',
#  'RACYU',
#  'IJUL',
#  'CSML',
#  'NULG',
#  'UST',
#  'DCF',
#  'GIM',
#  'WLTG',
#  'GDXU',
#  'PDBA',
#  'SNPX',
#  'SRRK',
#  'JPHY',
#  'QEFA',
#  'NFNT.W',
#  'RGTI',
#  'BMA',
#  'MD',
#  'AILV',
#  'ADEX.U',
#  'FNOV',
#  'BANX',
#  'WTMA',
#  'ZVIA',
#  'KAHC.U',
#  'HCMAU',
#  'PSAGW',
#  'TMAC',
#  'FRXB',
#  'UDR',
#  'FTSM',
#  'CNCE',
#  'ASR',
#  'MYNA',
#  'MLPR',
#  'AEIS',
#  'WAVSU',
#  'CDAQW',
#  'UCIB',
#  'CTAQ',
#  'GALT',
#  'MAIA',
#  'BSJR',
#  'JFR',
#  'OSS',
#  'POWI',
#  'ACGL',
#  'NIO',
#  'UMI',
#  'ACAXW',
#  'MSDA',
#  'DBRG$H',
#  'CBAY',
#  'BAC$S',
#  'MAN',
#  'STX',
#  'RC',
#  'PSMG',
#  'TRIS.U',
#  'BPACU',
#  'DS$B',
#  'EPI',
#  'ELA',
#  'DES',
#  'TREE',
#  'STT$D',
#  'OXSQG',
#  'EQRR',
#  'CORR$A',
#  'ZIONP',
#  'DHT',
#  'FATH.W',
#  'NTEST.B',
#  'SIFI',
#  'AIMC',
#  'NXGL',
#  'FA',
#  'VLDR',
#  'CDX',
#  'IBCE',
#  'PEAR',
#  'SIERW',
#  'PMVC.U',
#  'POND.W',
#  'RCFA.W',
#  'WELL',
#  'SITC$A',
#  'MOBBW',
#  'FSI',
#  'FLGC',
#  'PSFF',
#  'RYE',
#  'GRPH',
#  'ADFI',
#  'CJJD',
#  'MITT$A',
#  'DPST',
#  'CSD',
#  'CSBR',
#  'KOF',
#  'VNOM',
#  'RCOR.W',
#  'TGIF',
#  'DBA',
#  'VGR',
#  'DVN',
#  'INPX',
#  'FBRT$E',
#  'STTK',
#  'TROO',
#  'SBND',
#  'PAUG',
#  'BPTH',
#  'UBSI',
#  'TRFM',
#  'ACWF',
#  'SDY',
#  'IFGL',
#  'MOLN',
#  'CHEA',
#  'HTZWW',
#  'TMCI',
#  'AQNA',
#  'RYT',
#  'MSBIP',
#  'DRVN',
#  'SPBC',
#  'DSM',
#  'AXR',
#  'TYA',
#  'MOBVU',
#  'DXD',
#  'CLSN',
#  'MGTX',
#  'PFXNL',
#  'FLME',
#  'CHWY',
#  'EASG',
#  'PYS',
#  'ENTXW',
#  'KE',
#  'OPA.W',
#  'THQ',
#  'DFNV',
#  'SPYD',
#  'CURO',
#  'VZLA',
#  'KZR',
#  'FISV',
#  'DFAX',
#  'FHN$D',
#  'NHICW',
#  'SRLN',
#  'MGAM',
#  'VIRS',
#  'IMPX.U',
#  'AVTR',
#  'ESGG',
#  'IPVF',
#  'EMAN',
#  'ATNF',
#  'POW',
#  'LBAY',
#  'TRUP',
#  'UFPT',
#  'FAZ',
#  'MBB',
#  'DMYS.U',
#  'GWAV',
#  'SCZ',
#  'RAVE',
#  'VRE',
#  'COVAW',
#  'NTRB',
#  'AIP',
#  'ITIC',
#  'FEMS',
#  'TCRR',
#  'OFIX',
#  'HHGCW',
#  'INSW',
#  'RSG',
#  'VHAQ.R',
#  'OTEX',
#  'BJUN',
#  'GSRM',
#  'RMI',
#  'ARDX',
#  'FTAAU',
#  'OVV',
#  'TMFM',
#  'IBTL',
#  'RXRX',
#  'AHRNU',
#  'PERI',
#  'BVN',
#  'ALEC',
#  'TDTT',
#  'ZVO',
#  'TASK',
#  'IAK',
#  'VOOV',
#  'ESP',
#  'MEIP',
#  'WWE',
#  'SHO$H',
#  'MCAFU',
#  'AXS',
#  'GAB',
#  'ZBZX',
#  'IMUX',
#  'SMOG',
#  'ATA.U',
#  'ATFV',
#  'CETXP',
#  'HI',
#  'SIM',
#  'SCHN',
#  'DHC',
#  'UPW',
#  'EFSCP',
#  'SEIQ',
#  'TILL',
#  'CQP',
#  'CP',
#  'WLY',
#  'IBHI',
#  'ITB',
#  'PLAG',
#  'AFTR',
#  'TRTN$C',
#  'MSPRW',
#  'XVV',
#  'BPYPO',
#  'SANA',
#  'TDW',
#  'CIBR',
#  'PSA$F',
#  'IDV',
#  'NG',
#  'MH$D',
#  'EOI',
#  'DIM',
#  'CTGO',
#  'BOCN',
#  'CIXX',
#  'EFC$B',
#  'AZN',
#  'CMA',
#  'MSSA',
#  'VNLA',
#  'IBHE',
#  'ANET',
#  'VIXM',
#  'NHC',
#  'FCOM',
#  'SBEV.W',
#  'UPAR',
#  'FNWD',
#  'AZTA',
#  'EBON',
#  'OPA',
#  'CREXW',
#  'ONVO',
#  'EMCA',
#  'SWCH',
#  'PAHC',
#  'CLDT$A',
#  'CNOBP',
#  'MATW',
#  'FSSIW',
#  'ITQRU',
#  'VMAT',
#  'CPK',
#  'WTM',
#  'ATLCL',
#  'BOAC.U',
#  'CTEC',
#  'FSRD',
#  'PZN',
#  'FDHT',
#  'MITO',
#  'PBR',
#  'VSS',
#  'UEIC',
#  'NLS',
#  'TROW',
#  'RNR$F',
#  'BYN',
#  'AIQ',
#  'LADR',
#  'BDTX',
#  'ABVC',
#  'RCLFW',
#  'LOPX',
#  'CRSP',
#  'PHI',
#  'SXC',
#  'MSOX',
#  'GP',
#  'RWAY',
#  'OBE',
#  'NMTC',
#  'CNK',
#  'HIII',
#  'DILA',
#  'IVOL',
#  'ACHV',
#  'PAYO',
#  'LUNA',
#  'VMCAW',
#  'FMB',
#  'ISCG',
#  'RNST',
#  'TWKS',
#  'GPN',
#  'CSTR',
#  'EMP',
#  'AHT$F',
#  'RCL',
#  'MRNS',
#  'PEV',
#  'USEA',
#  'EQAL',
#  'TLGYW',
#  'CPUH.W',
#  'VLN.W',
#  'IQV',
#  'SAGAU',
#  'AGOV',
#  'SHUS',
#  'CONX',
#  'PSB$Y',
#  'SPLB',
#  'APGN',
#  'DFCF',
#  'MGI',
#  'FEAM',
#  'LBRDA',
#  'GLL',
#  'BWB',
#  'SOHON',
#  'GWH',
#  'EQHA.U',
#  'EVAV',
#  'SEDG',
#  'EVGRW',
#  'ONON',
#  'SCLE',
#  'KEY$J',
#  'SCCD',
#  'IVR$B',
#  'SABR',
#  'CND.W',
#  'BBW',
#  'JMSB',
#  'PACX',
#  'TFC$I',
#  'UNF',
#  'DRTSW',
#  'GMET',
#  'PYPL',
#  'NACP',
#  'FGMC',
#  'XDEC',
#  'OLP',
#  'EPHY',
#  'REXR',
#  'APGNW',
#  'VWO',
#  'KEUA',
#  'FBIOP',
#  'QLV',
#  'SPSK',
#  'DLA',
#  'FLQS',
#  'REE',
#  'BF.B',
#  'FAN',
#  'VINO',
#  'SEAT',
#  'SO',
#  'RMCF',
#  'CNHI',
#  'STAF',
#  'COF$N',
#  'KEMX',
#  'MTAC',
#  'GDOC',
#  'IYJ',
#  'SPXE',
#  'BWAQU',
#  'PBW',
#  'LOUP',
#  'GHAC',
#  'ENZL',
#  'GRP.U',
#  'PHDG',
#  'SGHL',
#  'CIF',
#  'FEMY',
#  'MNTK',
#  'FLBR',
#  'AYI',
#  'JJM',
#  'KAMN',
#  'CBZ',
#  'CLB',
#  'SIER',
#  'IXUS',
#  'SHUA',
#  'FSRXU',
#  'EGHT',
#  'RF$C',
#  'DILAU',
#  'JCTR',
#  'CCV',
#  'BGSF',
#  'IMAQ',
#  'IPVA',
#  'JMUB',
#  'GAINN',
#  'IJJ',
#  'IMPX',
#  'SWAR',
#  'DBND',
#  'ITUB',
#  'WEL.W',
#  'CCJ',
#  'ARMR',
#  'VAXX',
#  'IMTXW',
#  'PRAY',
#  'CORN',
#  'PEI$D',
#  'USEP',
#  'RHI',
#  'IFIN',
#  'KW',
#  'NRDS',
#  'XSOE',
#  'IDAT',
#  'TMDX',
#  'SHQAW',
#  'INDS',
#  'WKSP',
#  'GSJY',
#  'DDI',
#  'CMMB',
#  'AFGC',
#  'VBOCU',
#  'HCA',
#  'LRGE',
#  'SNCR',
#  'CTEST.L',
#  'MYSZ',
#  'QTRX',
#  'WD',
#  'KLIC',
#  'PUK',
#  'CHKP',
#  'NOCT',
#  'XDOC',
#  'FLGR',
#  'ARC',
#  'TBJL',
#  'CEE',
#  'TSAT',
#  'PRIM',
#  'ANAC',
#  'EWGS',
#  'QK',
#  'CRL',
#  'DSX',
#  'AIMDW',
#  'ARRWU',
#  'UKOMW',
#  'VIGL',
#  'IEMG',
#  'ACR$D',
#  'AZBO',
#  'IDBA',
#  'CMCAU',
#  'MYMD',
#  'LAAAU',
#  'KOCT',
#  'LAXXU',
#  'ON',
#  'OYST',
#  'SCOBU',
#  'NEU',
#  'HIPO',
#  'ORLY',
#  'DLR',
#  'AGNC',
#  'CHEK',
#  'AIVL',
#  'DIAL',
#  'PJT',
#  'ONEO',
#  'SSIC',
#  'RMT',
#  'DV',
#  'NVGS',
#  'RMMZ',
#  'STNG',
#  'QCLR',
#  'HOTH',
#  'DKNG',
#  'MLKN',
#  'TRNS',
#  'BPAY',
#  'VTWG',
#  'DZSI',
#  'OHAAW',
#  'HOUS',
#  'JPIB',
#  'LEGH',
#  'NOK',
#  'ACAD',
#  'EWBC',
#  'IEUR',
#  'GROW',
#  'HCP',
#  'ADP',
#  'DCTH',
#  'GBS',
#  'BAND',
#  'CPRX',
#  'LIDRW',
#  'MRTN',
#  'MVIS',
#  'NSPR',
#  'EGF',
#  'IVT',
#  'MOV',
#  'MPLX',
#  'NNY',
#  'FISK',
#  'VTVT',
#  'EVLVW',
#  'RCI',
#  'CNDB.W',
#  'KO',
#  'MIGI',
#  'FAF',
#  'DBEZ',
#  'UMC',
#  'VAC',
#  'APTMW',
#  'APXIU',
#  'JPIE',
#  'AL',
#  'JPEM',
#  'DXYN',
#  'XOSWW',
#  'CEAD',
#  'DAT',
#  'LCAHU',
#  'UCC',
#  'BOSC',
#  'STGW',
#  'SCCO',
#  'CPII',
#  'BRIV',
#  'IWS',
#  'IDLV',
#  'GPOR',
#  'LAZ',
#  'TOACU',
#  'MMIT',
#  'RVP',
#  'INDL',
#  'BRKH',
#  'SBII.U',
#  'SWETW',
#  'CVV',
#  'SMIHW',
#  'IMRN',
#  'SPRO',
#  'FIACU',
#  'TGI',
#  'VSAT',
#  'TCDA',
#  'DUETW',
#  'ALPN',
#  'JAQC',
#  'MGYR',
#  'ARGU',
#  'IFF',
#  'ATEC',
#  'BNE',
#  'BSCU',
#  'CFFN',
#  'BKTI',
#  'ATCX',
#  'SF$C',
#  'EGGF.W',
#  'HTPA.U',
#  'EEMX',
#  'GOGN.U',
#  'CMSA',
#  'PRIF$F',
#  'MANT',
#  'IRAA',
#  'ACIW',
#  'IEAWW',
#  'TMAC.W',
#  'RAVI',
#  'AHT',
#  'FHN$E',
#  'SLI',
#  'FL',
#  'SCHY',
#  'FEUS',
#  'GUNR',
#  'BLTS',
#  'EUO',
#  'ADSE',
#  'ENSC',
#  'LEGA',
#  'ATNFW',
#  'SUM',
#  'PJUN',
#  'PXH',
#  'SNV$D',
#  'OCSL',
#  'SLAC.W',
#  'VCEB',
#  'VIAO',
#  'ATAI',
#  'CERT',
#  'GDMA',
#  'HCARU',
#  'OPEN',
#  'IVAC',
#  'NEPT',
#  'DTW',
#  'IRDM',
#  'TZPS',
#  'CPAC',
#  'PY',
#  'EFTRW',
#  'TIME',
#  'LVOX',
#  'ROCLW',
#  'CMP',
#  'IGEB',
#  'EWU',
#  'CLRG',
#  'BND',
#  'BEPH',
#  'VINP',
#  'DOCU',
#  'DHF',
#  'SD',
#  'LAUR',
#  'ZINGU',
#  'HUBG',
#  'APH',
#  'SBFG',
#  'SNDL',
#  'EVLO',
#  'PWS',
#  'C',
#  'HT$E',
#  'JGGC',
#  'BLDR',
#  'DSAQ',
#  'EZM',
#  'SSXU',
#  'GBIL',
#  'HORI',
#  'LKQ',
#  'OVLH',
#  'WGMI',
#  'ESSCW',
#  'LNSR',
#  'ENOB',
#  'TOUR',
#  'MNA',
#  'CNYA',
#  'YTPG',
#  'AGBAW',
#  'VTAQU',
#  'KRYS',
#  'DS$C',
#  'CWEN',
#  ...}

# %%
my_list = ['W', 'R', 'P', 'Q']
del_set = set()
sav_set = set()

for symbol in symbols:
    if (len( symbol ) > 4 and symbol[-1] in my_list or "$" in symbol):
        del_set.add( symbol )
    else:
        sav_set.add( symbol )
        
p=pd.read_csv("shitlist")
p=list(p["0"])
del_set=del_set.union(p)
sav_set.difference_update(p)
print( f'Removed {len( del_set )} unqualified stock symbols...' )
print( f'There are {len( sav_set )} qualified stock symbols...' )
# Out:
# Removed 1592 unqualified stock symbols...
# There are 10606 qualified stock symbols...

# %%
#this just drops the odd empty string on the start
ticker_list=list(sav_set)[1:]
ticker_list
# Out:
# ['EL',
#  'ALLE',
#  'MXF',
#  'REMX',
#  'MLN',
#  'PIE',
#  'PINE',
#  'SONX',
#  'AMRN',
#  'VHAQ',
#  'SLYV',
#  'BSJN',
#  'LBAI',
#  'STE',
#  'ONB',
#  'DNUT',
#  'ICLK',
#  'NGC',
#  'CWEB',
#  'SAI',
#  'BJDX',
#  'NSC',
#  'MINV',
#  'CZNC',
#  'MTMT',
#  'FSBC',
#  'EZA',
#  'LEGR',
#  'NMRK',
#  'NECB',
#  'SBET',
#  'ZIG',
#  'FLRT',
#  'YCS',
#  'FSMB',
#  'PID',
#  'RIGZ',
#  'ERO',
#  'CBD',
#  'GRMN',
#  'IQSU',
#  'EPP',
#  'HYGW',
#  'SBBA',
#  'VIVE',
#  'IP',
#  'SPYG',
#  'SAL',
#  'BFI',
#  'ZHDG',
#  'FEMA',
#  'POET',
#  'IVR',
#  'IAE',
#  'PSTL',
#  'USI',
#  'IFRA',
#  'EDUT',
#  'FRWAU',
#  'AXTI',
#  'DFS',
#  'FLFR',
#  'GEF',
#  'GLRY',
#  'MFIN',
#  'SBUX',
#  'JRO',
#  'MDWD',
#  'HNNA',
#  'MNTS',
#  'WRAC.U',
#  'GBR',
#  'NFNT',
#  'SPE',
#  'WCN',
#  'NCMI',
#  'GSLC',
#  'API',
#  'HCKT',
#  'KREF',
#  'CFFI',
#  'VIOO',
#  'CLVR',
#  'FFWM',
#  'SMFL',
#  'PDN',
#  'EDNC',
#  'BIGZ',
#  'MAPS',
#  'VUZI',
#  'SPXT',
#  'IVCAU',
#  'SINT',
#  'LOCL',
#  'VISL',
#  'AFTR.U',
#  'AQB',
#  'QLTA',
#  'GTX',
#  'HIL',
#  'CENX',
#  'MFGP',
#  'TSLL',
#  'BGR',
#  'GXTG',
#  'MSGR',
#  'SMIG',
#  'DBEM',
#  'IVRA',
#  'AAPB',
#  'VXX',
#  'TTAC',
#  'DHI',
#  'RMGC',
#  'HBNC',
#  'IGA',
#  'OLED',
#  'SLN',
#  'CLSE',
#  'TLH',
#  'SIO',
#  'HYZD',
#  'IQI',
#  'SCRM',
#  'LWLG',
#  'HNST',
#  'KRTX',
#  'KZIA',
#  'TBCP',
#  'CSX',
#  'GIB',
#  'NNVC',
#  'EW',
#  'ITW',
#  'UBND',
#  'VOD',
#  'LAC',
#  'EDTXU',
#  'TXRH',
#  'TCFC',
#  'USCTU',
#  'HCIC',
#  'CCRN',
#  'FSS',
#  'NSSC',
#  'SCAQU',
#  'PWV',
#  'FLYA',
#  'GATX',
#  'BHLB',
#  'CLDT',
#  'PAFOU',
#  'VLY',
#  'WBIY',
#  'CNO',
#  'NVR',
#  'MMX',
#  'PCSA',
#  'TILE',
#  'MEXX',
#  'XTLB',
#  'APTV',
#  'LCF',
#  'XDNA',
#  'GLYC',
#  'DWMF',
#  'SPKB',
#  'ASO',
#  'OI',
#  'SMWB',
#  'SANG',
#  'PSCJ',
#  'PNFP',
#  'IXN',
#  'AXGN',
#  'VPN',
#  'FSRX',
#  'MHH',
#  'HDSN',
#  'FCCO',
#  'MTBC',
#  'HAS',
#  'ELV',
#  'IMCG',
#  'RS',
#  'TCPC',
#  'EKAR',
#  'GTHX',
#  'WSFS',
#  'PANL',
#  'TSM',
#  'PJUL',
#  'GNMA',
#  'RKT',
#  'AVHI',
#  'DECAU',
#  'GEEX',
#  'TELA',
#  'HTD',
#  'AEAEU',
#  'CEA',
#  'SMMT',
#  'LEXI',
#  'CIRC',
#  'BYM',
#  'GASS',
#  'FWP',
#  'SIXS',
#  'DM',
#  'IMH',
#  'GWII',
#  'HONE',
#  'HMPT',
#  'ROCAU',
#  'SPY',
#  'FFHG',
#  'REV',
#  'CLFD',
#  'QPX',
#  'GCP',
#  'CLDL',
#  'CASI',
#  'STRT',
#  'PBFX',
#  'BYNO',
#  'BYOB',
#  'RJA',
#  'CII',
#  'SWSSU',
#  'PHYS',
#  'LYT',
#  'LFG',
#  'SABS',
#  'LLL',
#  'CACI',
#  'NSTG',
#  'MXCT',
#  'MDLZ',
#  'LYLT',
#  'PSCX',
#  'KMI',
#  'RSX',
#  'GWRE',
#  'FVIV',
#  'BSFC',
#  'SSYS',
#  'AMTX',
#  'GGMCU',
#  'ZAZZT',
#  'IVCA',
#  'ACP',
#  'SCOR',
#  'MEAR',
#  'DNAB',
#  'AMLP',
#  'SRVR',
#  'VFQY',
#  'EWO',
#  'SHAP.U',
#  'AVAH',
#  'SLNH',
#  'IGI',
#  'FENG',
#  'KNGS',
#  'AXLA',
#  'SKYT',
#  'BSMR',
#  'EPRE',
#  'KHYB',
#  'USAI',
#  'JZRO',
#  'SCUA.U',
#  'PEP',
#  'RACYU',
#  'IJUL',
#  'CSML',
#  'NULG',
#  'UST',
#  'DCF',
#  'GIM',
#  'WLTG',
#  'GDXU',
#  'PDBA',
#  'SNPX',
#  'SRRK',
#  'JPHY',
#  'QEFA',
#  'RGTI',
#  'BMA',
#  'MD',
#  'AILV',
#  'ADEX.U',
#  'FNOV',
#  'BANX',
#  'WTMA',
#  'ZVIA',
#  'KAHC.U',
#  'HCMAU',
#  'TMAC',
#  'FRXB',
#  'UDR',
#  'FTSM',
#  'CNCE',
#  'ASR',
#  'MYNA',
#  'MLPR',
#  'AEIS',
#  'WAVSU',
#  'UCIB',
#  'CTAQ',
#  'GALT',
#  'MAIA',
#  'BSJR',
#  'JFR',
#  'OSS',
#  'POWI',
#  'ACGL',
#  'NIO',
#  'UMI',
#  'MSDA',
#  'CBAY',
#  'MAN',
#  'STX',
#  'RC',
#  'PSMG',
#  'TRIS.U',
#  'BPACU',
#  'EPI',
#  'ELA',
#  'DES',
#  'TREE',
#  'OXSQG',
#  'EQRR',
#  'DHT',
#  'NTEST.B',
#  'SIFI',
#  'AIMC',
#  'NXGL',
#  'FA',
#  'VLDR',
#  'CDX',
#  'IBCE',
#  'PEAR',
#  'PMVC.U',
#  'WELL',
#  'FSI',
#  'FLGC',
#  'PSFF',
#  'RYE',
#  'GRPH',
#  'ADFI',
#  'CJJD',
#  'DPST',
#  'CSD',
#  'CSBR',
#  'KOF',
#  'VNOM',
#  'TGIF',
#  'DBA',
#  'VGR',
#  'DVN',
#  'INPX',
#  'STTK',
#  'TROO',
#  'SBND',
#  'PAUG',
#  'BPTH',
#  'UBSI',
#  'TRFM',
#  'ACWF',
#  'SDY',
#  'IFGL',
#  'MOLN',
#  'CHEA',
#  'TMCI',
#  'AQNA',
#  'RYT',
#  'DRVN',
#  'SPBC',
#  'DSM',
#  'AXR',
#  'TYA',
#  'MOBVU',
#  'DXD',
#  'CLSN',
#  'MGTX',
#  'PFXNL',
#  'FLME',
#  'CHWY',
#  'EASG',
#  'PYS',
#  'KE',
#  'THQ',
#  'DFNV',
#  'SPYD',
#  'CURO',
#  'VZLA',
#  'KZR',
#  'FISV',
#  'DFAX',
#  'SRLN',
#  'MGAM',
#  'VIRS',
#  'IMPX.U',
#  'AVTR',
#  'ESGG',
#  'IPVF',
#  'EMAN',
#  'ATNF',
#  'POW',
#  'LBAY',
#  'TRUP',
#  'UFPT',
#  'FAZ',
#  'MBB',
#  'DMYS.U',
#  'GWAV',
#  'SCZ',
#  'RAVE',
#  'VRE',
#  'NTRB',
#  'AIP',
#  'ITIC',
#  'FEMS',
#  'TCRR',
#  'OFIX',
#  'INSW',
#  'RSG',
#  'OTEX',
#  'BJUN',
#  'GSRM',
#  'RMI',
#  'ARDX',
#  'FTAAU',
#  'OVV',
#  'TMFM',
#  'IBTL',
#  'RXRX',
#  'AHRNU',
#  'PERI',
#  'BVN',
#  'ALEC',
#  'TDTT',
#  'ZVO',
#  'TASK',
#  'IAK',
#  'VOOV',
#  'ESP',
#  'MEIP',
#  'WWE',
#  'MCAFU',
#  'AXS',
#  'GAB',
#  'IMUX',
#  'SMOG',
#  'ATA.U',
#  'ATFV',
#  'HI',
#  'SIM',
#  'SCHN',
#  'DHC',
#  'UPW',
#  'SEIQ',
#  'TILL',
#  'CQP',
#  'CP',
#  'WLY',
#  'IBHI',
#  'ITB',
#  'PLAG',
#  'AFTR',
#  'XVV',
#  'BPYPO',
#  'SANA',
#  'TDW',
#  'CIBR',
#  'IDV',
#  'NG',
#  'EOI',
#  'DIM',
#  'CTGO',
#  'BOCN',
#  'CIXX',
#  'AZN',
#  'CMA',
#  'MSSA',
#  'VNLA',
#  'IBHE',
#  'ANET',
#  'VIXM',
#  'NHC',
#  'FCOM',
#  'UPAR',
#  'FNWD',
#  'AZTA',
#  'EBON',
#  'OPA',
#  'ONVO',
#  'EMCA',
#  'SWCH',
#  'PAHC',
#  'MATW',
#  'ITQRU',
#  'VMAT',
#  'CPK',
#  'WTM',
#  'ATLCL',
#  'BOAC.U',
#  'CTEC',
#  'FSRD',
#  'PZN',
#  'FDHT',
#  'MITO',
#  'PBR',
#  'VSS',
#  'UEIC',
#  'NLS',
#  'TROW',
#  'BYN',
#  'AIQ',
#  'LADR',
#  'BDTX',
#  'ABVC',
#  'LOPX',
#  'CRSP',
#  'PHI',
#  'SXC',
#  'MSOX',
#  'GP',
#  'RWAY',
#  'OBE',
#  'NMTC',
#  'CNK',
#  'HIII',
#  'DILA',
#  'IVOL',
#  'ACHV',
#  'PAYO',
#  'LUNA',
#  'FMB',
#  'ISCG',
#  'RNST',
#  'TWKS',
#  'GPN',
#  'CSTR',
#  'EMP',
#  'RCL',
#  'MRNS',
#  'PEV',
#  'USEA',
#  'EQAL',
#  'IQV',
#  'SAGAU',
#  'AGOV',
#  'SHUS',
#  'CONX',
#  'SPLB',
#  'APGN',
#  'DFCF',
#  'MGI',
#  'FEAM',
#  'LBRDA',
#  'GLL',
#  'BWB',
#  'SOHON',
#  'GWH',
#  'EQHA.U',
#  'EVAV',
#  'SEDG',
#  'ONON',
#  'SCLE',
#  'SCCD',
#  'SABR',
#  'BBW',
#  'JMSB',
#  'PACX',
#  'UNF',
#  'GMET',
#  'PYPL',
#  'NACP',
#  'FGMC',
#  'XDEC',
#  'OLP',
#  'EPHY',
#  'REXR',
#  'VWO',
#  'KEUA',
#  'QLV',
#  'SPSK',
#  'DLA',
#  'FLQS',
#  'REE',
#  'BF.B',
#  'FAN',
#  'VINO',
#  'SEAT',
#  'SO',
#  'RMCF',
#  'CNHI',
#  'STAF',
#  'KEMX',
#  'MTAC',
#  'GDOC',
#  'IYJ',
#  'SPXE',
#  'BWAQU',
#  'PBW',
#  'LOUP',
#  'GHAC',
#  'ENZL',
#  'PHDG',
#  'SGHL',
#  'CIF',
#  'FEMY',
#  'MNTK',
#  'FLBR',
#  'AYI',
#  'JJM',
#  'KAMN',
#  'CBZ',
#  'CLB',
#  'SIER',
#  'IXUS',
#  'SHUA',
#  'FSRXU',
#  'EGHT',
#  'DILAU',
#  'JCTR',
#  'CCV',
#  'BGSF',
#  'IMAQ',
#  'IPVA',
#  'JMUB',
#  'GAINN',
#  'IJJ',
#  'IMPX',
#  'SWAR',
#  'DBND',
#  'ITUB',
#  'CCJ',
#  'ARMR',
#  'VAXX',
#  'PRAY',
#  'CORN',
#  'USEP',
#  'RHI',
#  'IFIN',
#  'KW',
#  'NRDS',
#  'XSOE',
#  'IDAT',
#  'TMDX',
#  'INDS',
#  'WKSP',
#  'GSJY',
#  'DDI',
#  'CMMB',
#  'AFGC',
#  'VBOCU',
#  'HCA',
#  'LRGE',
#  'SNCR',
#  'CTEST.L',
#  'MYSZ',
#  'QTRX',
#  'WD',
#  'KLIC',
#  'PUK',
#  'CHKP',
#  'NOCT',
#  'XDOC',
#  'FLGR',
#  'ARC',
#  'TBJL',
#  'CEE',
#  'TSAT',
#  'PRIM',
#  'ANAC',
#  'EWGS',
#  'QK',
#  'CRL',
#  'DSX',
#  'ARRWU',
#  'VIGL',
#  'IEMG',
#  'AZBO',
#  'IDBA',
#  'CMCAU',
#  'MYMD',
#  'LAAAU',
#  'KOCT',
#  'LAXXU',
#  'ON',
#  'OYST',
#  'SCOBU',
#  'NEU',
#  'HIPO',
#  'ORLY',
#  'DLR',
#  'AGNC',
#  'CHEK',
#  'AIVL',
#  'DIAL',
#  'PJT',
#  'ONEO',
#  'SSIC',
#  'RMT',
#  'DV',
#  'NVGS',
#  'RMMZ',
#  'STNG',
#  'QCLR',
#  'HOTH',
#  'DKNG',
#  'MLKN',
#  'TRNS',
#  'BPAY',
#  'VTWG',
#  'DZSI',
#  'HOUS',
#  'JPIB',
#  'LEGH',
#  'NOK',
#  'ACAD',
#  'EWBC',
#  'IEUR',
#  'GROW',
#  'HCP',
#  'ADP',
#  'DCTH',
#  'GBS',
#  'BAND',
#  'CPRX',
#  'MRTN',
#  'MVIS',
#  'NSPR',
#  'EGF',
#  'IVT',
#  'MOV',
#  'MPLX',
#  'NNY',
#  'FISK',
#  'VTVT',
#  'RCI',
#  'KO',
#  'MIGI',
#  'FAF',
#  'DBEZ',
#  'UMC',
#  'VAC',
#  'APXIU',
#  'JPIE',
#  'AL',
#  'JPEM',
#  'DXYN',
#  'CEAD',
#  'DAT',
#  'LCAHU',
#  'UCC',
#  'BOSC',
#  'STGW',
#  'SCCO',
#  'CPII',
#  'BRIV',
#  'IWS',
#  'IDLV',
#  'GPOR',
#  'LAZ',
#  'TOACU',
#  'MMIT',
#  'RVP',
#  'INDL',
#  'BRKH',
#  'SBII.U',
#  'CVV',
#  'IMRN',
#  'SPRO',
#  'FIACU',
#  'TGI',
#  'VSAT',
#  'TCDA',
#  'ALPN',
#  'JAQC',
#  'MGYR',
#  'ARGU',
#  'IFF',
#  'ATEC',
#  'BNE',
#  'BSCU',
#  'CFFN',
#  'BKTI',
#  'ATCX',
#  'HTPA.U',
#  'EEMX',
#  'GOGN.U',
#  'CMSA',
#  'MANT',
#  'IRAA',
#  'ACIW',
#  'RAVI',
#  'AHT',
#  'SLI',
#  'FL',
#  'SCHY',
#  'FEUS',
#  'GUNR',
#  'BLTS',
#  'EUO',
#  'ADSE',
#  'ENSC',
#  'LEGA',
#  'SUM',
#  'PJUN',
#  'PXH',
#  'VCEB',
#  'OCSL',
#  'VIAO',
#  'ATAI',
#  'CERT',
#  'GDMA',
#  'HCARU',
#  'OPEN',
#  'IVAC',
#  'NEPT',
#  'DTW',
#  'IRDM',
#  'TZPS',
#  'CPAC',
#  'PY',
#  'TIME',
#  'LVOX',
#  'CMP',
#  'IGEB',
#  'EWU',
#  'CLRG',
#  'BND',
#  'BEPH',
#  'VINP',
#  'DOCU',
#  'DHF',
#  'SD',
#  'LAUR',
#  'ZINGU',
#  'HUBG',
#  'APH',
#  'SBFG',
#  'SNDL',
#  'EVLO',
#  'PWS',
#  'C',
#  'JGGC',
#  'BLDR',
#  'DSAQ',
#  'EZM',
#  'SSXU',
#  'GBIL',
#  'HORI',
#  'LKQ',
#  'OVLH',
#  'WGMI',
#  'LNSR',
#  'ENOB',
#  'TOUR',
#  'MNA',
#  'CNYA',
#  'YTPG',
#  'VTAQU',
#  'KRYS',
#  'CWEN',
#  'FFHL',
#  'EDI',
#  'OILD',
#  'RPHM',
#  'ACII',
#  'FCAX.U',
#  'ARTNA',
#  'HTY',
#  'FRDM',
#  'BZQ',
#  'ACT',
#  'JPS',
#  'SEIC',
#  'WPS',
#  'QEMM',
#  'IVDA',
#  'BSDE',
#  'SCUA',
#  'IBB',
#  'AMNB',
#  'FDVV',
#  'WNNR',
#  'LEV',
#  'GMBLZ',
#  'TRONU',
#  'IPG',
#  'DSL',
#  'HWKZ.U',
#  'ZTR',
#  'PNRG',
#  'ESI',
#  'ELF',
#  'ULTA',
#  'IRAAU',
#  'BKSE',
#  'LLY',
#  'TMUS',
#  'EWSC',
#  'DEMZ',
#  'TOI',
#  'PPL',
#  'LYFE',
#  'RDFN',
#  'PXS',
#  'NDVG',
#  'LVACU',
#  'MMIN',
#  'HMOP',
#  'VSTA',
#  'IBN',
#  'TBLA',
#  'PTRB',
#  'DSAQ.U',
#  'RDN',
#  'KGRN',
#  'QUS',
#  'CENQ',
#  'KYCHU',
#  'AAOI',
#  'BBUC',
#  'IMMP',
#  'PAVMZ',
#  'HTOO',
#  'EFX',
#  'OMCL',
#  'FRAF',
#  'RSSS',
#  'AKAN',
#  'SNCY',
#  'QNGY',
#  'AGBA',
#  'VJET',
#  'CTLT',
#  'DTC',
#  'NGL',
#  'FCT',
#  'KSTR',
#  'OFSSH',
#  'SANW',
#  'GERM',
#  'SUPL',
#  'BGY',
#  'MIMO.A',
#  'AKAM',
#  'VTRU',
#  'AUR',
#  'CARZ',
#  'FNHC',
#  'EVO',
#  'NVQ',
#  'MTAL.U',
#  'GFI',
#  'AMSWA',
#  'NSTD.U',
#  'LIT',
#  'MEACU',
#  'GLOB',
#  'FNDA',
#  'AGCO',
#  'WSC',
#  'FMS',
#  'ENCPU',
#  'TUYA',
#  'IPOS',
#  'SXQG',
#  'REFI',
#  'ISCV',
#  'HYZN',
#  'TBNK',
#  'DBJA',
#  'GECCO',
#  'ODDS',
#  'ZBZZT',
#  'IVES',
#  'MACK',
#  'NVVE',
#  'CEPU',
#  'RKDA',
#  'ILCG',
#  'MBAC.U',
#  'BKU',
#  'PTVE',
#  'SFYX',
#  'QRTEA',
#  'CTEST.S',
#  'VMI',
#  'EWC',
#  'HYS',
#  'TNDM',
#  'MCR',
#  'NCZ',
#  ...]

# %% [markdown]
# # fetching data
#
# we are scraping yahoo finance for the data
#
# there are some repeat trys to get the right ticker format
#
#
# .
#
# I implemented some basic multithreading to speed this up
#
# its not much but it helps

# %%
start='01/01/2020' 
end='09/14/2022'

# %%
import concurrent.futures 

def get_seiries(ticker,start,end,entry="adjclose"):
    try:
        raw = get_data(ticker.split(".")[0], start_date=start, end_date=end)[entry]
    except: 
        try:
            raw = get_data(ticker.replace(".","-"), start_date=start, end_date=end)[entry]
        except:
            raw = get_data(ticker[0:4], start_date=start, end_date=end)[entry]
    return raw/raw[0]

def get_df(l,start,end,entry="adjclose"):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        x=[executor.submit(lambda x: get_seiries(x,start,end,entry=entry),name)for name in l]
        x=[a.result() for a in x]
    for i,c in enumerate(x):
        c.name=l[i]
    return pd.DataFrame(x).transpose()
y=get_df(ticker_list[2000:2100],start,end,entry="adjclose")
y
# Out:
#               CLBR.U      FEBZ     FNVTU      FMAO      INTU      FTHY  \
# 2020-01-02       NaN       NaN       NaN  1.000000  1.000000       NaN
# 2020-01-03       NaN       NaN       NaN  0.976253  0.993312       NaN
# 2020-01-06       NaN       NaN       NaN  0.978232  1.000939       NaN
# 2020-01-07       NaN       NaN       NaN  0.966689  1.001165       NaN
# 2020-01-08       NaN       NaN       NaN  0.975264  1.025248       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-09-07  1.012435  1.076099  0.997024  0.948012  1.654820  0.798128
# 2022-09-08  1.012435  1.079738  0.997024  0.948357  1.669076  0.800797
# 2022-09-09  1.008290  1.091694  0.997024  0.958703  1.710857  0.798128
# 2022-09-12  1.010363  1.097533  0.993056  0.962496  1.731157  0.798128
# 2022-09-13  1.006218  1.068261  0.993056  0.938356  1.632086  0.784781
#
#                  KSS      IDHD      IRWD       UGA  ...      PSMC       WIP  \
# 2020-01-02  1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 2020-01-03  1.001629  1.003049  0.993967  1.027974  ...  1.001942  1.001087
# 2020-01-06  1.019344  1.011733  1.056561  1.024593  ...  1.000544  1.005073
# 2020-01-07  1.021584  1.000354  1.006033  1.010145  ...  1.000388  0.999275
# 2020-01-08  1.005498  1.002375  0.991704  0.980941  ...  1.000777  0.997645
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-09-07  0.636615  0.867705  0.806184  1.546265  ...  0.991097  0.804788
# 2022-09-08  0.645646  0.865507  0.827300  1.557947  ...  0.987864  0.794823
# 2022-09-09  0.660265  0.880891  0.829563  1.626499  ...  0.993522  0.803472
# 2022-09-12  0.664565  0.885817  0.831071  1.651706  ...  0.995948  0.801592
# 2022-09-13  0.618770  0.865356  0.819004  1.667077  ...  0.982205  0.787865
#
#                 NTWK     ESACU      SCCE      CGUS      MSTB      TSBK  \
# 2020-01-02  1.000000       NaN       NaN       NaN       NaN  1.000000
# 2020-01-03  0.983051       NaN       NaN       NaN       NaN  0.976843
# 2020-01-06  0.963680       NaN       NaN       NaN       NaN  0.961839
# 2020-01-07  0.932203       NaN       NaN       NaN       NaN  0.958904
# 2020-01-08  0.895884       NaN       NaN       NaN       NaN  0.965427
# ...              ...       ...       ...       ...       ...       ...
# 2022-09-07  0.888620  1.003980  0.929293  0.911228  1.040355  0.933875
# 2022-09-08  0.903148  1.003980  0.933333  0.916092  1.046223  0.928978
# 2022-09-09  0.878935  1.013930  0.943434  0.931496  1.059455  0.944718
# 2022-09-12  0.907990  1.008955  0.934949  0.940008  1.067062  0.945067
# 2022-09-13  0.891041  1.012935  0.930909  0.903527  1.036713  0.946816
#
#                 KBND      NETZ
# 2020-01-02  1.000000       NaN
# 2020-01-03  0.997863       NaN
# 2020-01-06  1.000000       NaN
# 2020-01-07  1.003206       NaN
# 2020-01-08  1.005496       NaN
# ...              ...       ...
# 2022-09-07  0.972979  1.050112
# 2022-09-08  0.973440  1.062238
# 2022-09-09  0.971132  1.076136
# 2022-09-12  0.988677  1.079376
# 2022-09-13  0.968516  1.052639
#
# [680 rows x 100 columns]

# %%
def time_encode(t):
    first= [(a.day_of_week,a.day/30,a.month/12,(a.year-2020)) for a in t]
    return [[x[i] for x in first] for i in range(4)]
time_encode(y.index[0:5])
# Out:
# [[3, 4, 0, 1, 2],
#  [0.06666666666666667, 0.1, 0.2, 0.23333333333333334, 0.26666666666666666],
#  [0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333,
#   0.08333333333333333],
#  [0, 0, 0, 0, 0]]

# %%
look=layers.StringLookup(vocabulary=ticker_list)
inv_look=layers.StringLookup(vocabulary=ticker_list,invert=True)
tick_embed=layers.Embedding(len(ticker_list)+1,512,embeddings_constraint= tf.keras.constraints.unit_norm)

day_embed=layers.Embedding(7,10)

# %% [markdown]
# # secondry testing for errors

# %%
segmented_dfs=[]
shitlist=[]
for i in range(0,len(ticker_list)-100,100):
    try:
        segmented_dfs.append(get_df(ticker_list[i:i+100],start,end,entry="adjclose"))
        print(i)
    except: 
        print(f"error at {i}")
        shitlist.append(i)
#total_df.to_csv(f"prices: {start} to {end}.csv")

# %%
print("yay")

# %%
#get_df(ticker_list[10600],start,end,entry="adjclose")
extra=set(range(10600,len(ticker_list)))
extra

# %%
x=[set(range(i,i+100)) for i in shitlist]
x.append(extra)
x=set.union(*x)
x

# %%
with concurrent.futures.ThreadPoolExecutor() as executor: 
    t=[executor.submit(lambda x: get_seiries(x,start,end,entry="adjclose"),ticker_list[i]) for i in x]

# %%
del(t)
